# %% [markdown]
# # Text Preprocessing

# %%
import nltk
import string
from collections import Counter

# %%
raw_text = "Rick and Morty is an American adult animated science fiction sitcom created by Justin Roiland and Dan Harmon for Cartoon Network's nighttime programming block Adult Swim. The series follows the misadventures of Rick Sanchez, a cynical mad scientist, and his good-hearted but fretful grandson Morty Smith, who split their time between domestic life and interdimensional adventures that take place across an infinite number of realities, often traveling to other planets and dimensions through portals and on Rick's flying saucer. The general concept of Rick and Morty relies on two conflicting scenarios: domestic family drama, and a misanthropic grandfather dragging his grandson into hijinks.Roiland voiced the eponymous characters, with Chris Parnell, Spencer Grammer, and Sarah Chalke voicing the rest of Rick and Morty's family. The series originated from an animated short parody film of Back to the Future created by Roiland for Channel 101, a short-film festival cofounded by Harmon. Since its debut, the series has received critical acclaim for its originality, creativity, and humor. It has been nominated for three Primetime Emmy Awards for Outstanding Animated Program and won the award in 2018 and 2020. The series has also received two Annie Awards. At times, the series has been the most viewed television comedy for adults between 18 and 24. The popularity of Rick and Morty has made it a hundred-million dollar merchandising and media franchise.The sixth season premiered on September 4, 2022, and consists of ten episodes. A seventh season was confirmed as part of a long-term deal with Cartoon Network that ordered 70 new episodes, which renewed the series through to a tenth season. Adult Swim cut ties with Roiland in 2023 amid allegations of domestic abuse and announced it would be recasting his roles with soundalike actors."

# %%
print(raw_text)
# Out:
# Rick and Morty is an American adult animated science fiction sitcom created by Justin Roiland and Dan Harmon for Cartoon Network's nighttime programming block Adult Swim. The series follows the misadventures of Rick Sanchez, a cynical mad scientist, and his good-hearted but fretful grandson Morty Smith, who split their time between domestic life and interdimensional adventures that take place across an infinite number of realities, often traveling to other planets and dimensions through portals and on Rick's flying saucer. The general concept of Rick and Morty relies on two conflicting scenarios: domestic family drama, and a misanthropic grandfather dragging his grandson into hijinks.Roiland voiced the eponymous characters, with Chris Parnell, Spencer Grammer, and Sarah Chalke voicing the rest of Rick and Morty's family. The series originated from an animated short parody film of Back to the Future created by Roiland for Channel 101, a short-film festival cofounded by Harmon. Since its debut, the series has received critical acclaim for its originality, creativity, and humor. It has been nominated for three Primetime Emmy Awards for Outstanding Animated Program and won the award in 2018 and 2020. The series has also received two Annie Awards. At times, the series has been the most viewed television comedy for adults between 18 and 24. The popularity of Rick and Morty has made it a hundred-million dollar merchandising and media franchise.The sixth season premiered on September 4, 2022, and consists of ten episodes. A seventh season was confirmed as part of a long-term deal with Cartoon Network that ordered 70 new episodes, which renewed the series through to a tenth season. Adult Swim cut ties with Roiland in 2023 amid allegations of domestic abuse and announced it would be recasting his roles with soundalike actors.

# %% [markdown]
# ## Sentence splitting

# %% [markdown]
# Splitting text into sentences.

# %%
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jaspe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = sent_tokenize(raw_text)

# %%
print(f'There are {len(sentences)} sentences')
# Out:
# There are 11 sentences

# %% [markdown]
# ## Tokenisation

# %% [markdown]
# Dividing a string into a list of tokens.

# %%
from nltk.tokenize import word_tokenize

# %%
tokens_list = [word_tokenize(s) for s in sentences]

# %%
tokens_list
# Out:
# [['Rick',
#   'and',
#   'Morty',
#   'is',
#   'an',
#   'American',
#   'adult',
#   'animated',
#   'science',
#   'fiction',
#   'sitcom',
#   'created',
#   'by',
#   'Justin',
#   'Roiland',
#   'and',
#   'Dan',
#   'Harmon',
#   'for',
#   'Cartoon',
#   'Network',
#   "'s",
#   'nighttime',
#   'programming',
#   'block',
#   'Adult',
#   'Swim',
#   '.'],
#  ['The',
#   'series',
#   'follows',
#   'the',
#   'misadventures',
#   'of',
#   'Rick',
#   'Sanchez',
#   ',',
#   'a',
#   'cynical',
#   'mad',
#   'scientist',
#   ',',
#   'and',
#   'his',
#   'good-hearted',
#   'but',
#   'fretful',
#   'grandson',
#   'Morty',
#   'Smith',
#   ',',
#   'who',
#   'split',
#   'their',
#   'time',
#   'between',
#   'domestic',
#   'life',
#   'and',
#   'interdimensional',
#   'adventures',
#   'that',
#   'take',
#   'place',
#   'across',
#   'an',
#   'infinite',
#   'number',
#   'of',
#   'realities',
#   ',',
#   'often',
#   'traveling',
#   'to',
#   'other',
#   'planets',
#   'and',
#   'dimensions',
#   'through',
#   'portals',
#   'and',
#   'on',
#   'Rick',
#   "'s",
#   'flying',
#   'saucer',
#   '.'],
#  ['The',
#   'general',
#   'concept',
#   'of',
#   'Rick',
#   'and',
#   'Morty',
#   'relies',
#   'on',
#   'two',
#   'conflicting',
#   'scenarios',
#   ':',
#   'domestic',
#   'family',
#   'drama',
#   ',',
#   'and',
#   'a',
#   'misanthropic',
#   'grandfather',
#   'dragging',
#   'his',
#   'grandson',
#   'into',
#   'hijinks.Roiland',
#   'voiced',
#   'the',
#   'eponymous',
#   'characters',
#   ',',
#   'with',
#   'Chris',
#   'Parnell',
#   ',',
#   'Spencer',
#   'Grammer',
#   ',',
#   'and',
#   'Sarah',
#   'Chalke',
#   'voicing',
#   'the',
#   'rest',
#   'of',
#   'Rick',
#   'and',
#   'Morty',
#   "'s",
#   'family',
#   '.'],
#  ['The',
#   'series',
#   'originated',
#   'from',
#   'an',
#   'animated',
#   'short',
#   'parody',
#   'film',
#   'of',
#   'Back',
#   'to',
#   'the',
#   'Future',
#   'created',
#   'by',
#   'Roiland',
#   'for',
#   'Channel',
#   '101',
#   ',',
#   'a',
#   'short-film',
#   'festival',
#   'cofounded',
#   'by',
#   'Harmon',
#   '.'],
#  ['Since',
#   'its',
#   'debut',
#   ',',
#   'the',
#   'series',
#   'has',
#   'received',
#   'critical',
#   'acclaim',
#   'for',
#   'its',
#   'originality',
#   ',',
#   'creativity',
#   ',',
#   'and',
#   'humor',
#   '.'],
#  ['It',
#   'has',
#   'been',
#   'nominated',
#   'for',
#   'three',
#   'Primetime',
#   'Emmy',
#   'Awards',
#   'for',
#   'Outstanding',
#   'Animated',
#   'Program',
#   'and',
#   'won',
#   'the',
#   'award',
#   'in',
#   '2018',
#   'and',
#   '2020',
#   '.'],
#  ['The', 'series', 'has', 'also', 'received', 'two', 'Annie', 'Awards', '.'],
#  ['At',
#   'times',
#   ',',
#   'the',
#   'series',
#   'has',
#   'been',
#   'the',
#   'most',
#   'viewed',
#   'television',
#   'comedy',
#   'for',
#   'adults',
#   'between',
#   '18',
#   'and',
#   '24',
#   '.'],
#  ['The',
#   'popularity',
#   'of',
#   'Rick',
#   'and',
#   'Morty',
#   'has',
#   'made',
#   'it',
#   'a',
#   'hundred-million',
#   'dollar',
#   'merchandising',
#   'and',
#   'media',
#   'franchise.The',
#   'sixth',
#   'season',
#   'premiered',
#   'on',
#   'September',
#   '4',
#   ',',
#   '2022',
#   ',',
#   'and',
#   'consists',
#   'of',
#   'ten',
#   'episodes',
#   '.'],
#  ['A',
#   'seventh',
#   'season',
#   'was',
#   'confirmed',
#   'as',
#   'part',
#   'of',
#   'a',
#   'long-term',
#   'deal',
#   'with',
#   'Cartoon',
#   'Network',
#   'that',
#   'ordered',
#   '70',
#   'new',
#   'episodes',
#   ',',
#   'which',
#   'renewed',
#   'the',
#   'series',
#   'through',
#   'to',
#   'a',
#   'tenth',
#   'season',
#   '.'],
#  ['Adult',
#   'Swim',
#   'cut',
#   'ties',
#   'with',
#   'Roiland',
#   'in',
#   '2023',
#   'amid',
#   'allegations',
#   'of',
#   'domestic',
#   'abuse',
#   'and',
#   'announced',
#   'it',
#   'would',
#   'be',
#   'recasting',
#   'his',
#   'roles',
#   'with',
#   'soundalike',
#   'actors',
#   '.']]

# %% [markdown]
# The top-10 most common tokens.

# %%
Counter([w for x in tokens_list for w in x]).most_common(10)
# Out:
# [('and', 18),
#  (',', 16),
#  ('.', 11),
#  ('the', 9),
#  ('of', 9),
#  ('Rick', 6),
#  ('for', 6),
#  ('series', 6),
#  ('a', 6),
#  ('Morty', 5)]

# %% [markdown]
# ## Removing punctuation and stop words

# %% [markdown]
# Stopwords and punctuation are usually not helpful for many IR tasks, and removing them can reduce the number of tokens we need to process.

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jaspe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords_en = set(stopwords.words('english'))

# %%
stopwords_en
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
tokens_list[:] = [[w for w in x if w not in string.punctuation and w not in stopwords_en] for x in tokens_list]

# %%
tokens_list
# Out:
# [['Rick',
#   'Morty',
#   'American',
#   'adult',
#   'animated',
#   'science',
#   'fiction',
#   'sitcom',
#   'created',
#   'Justin',
#   'Roiland',
#   'Dan',
#   'Harmon',
#   'Cartoon',
#   'Network',
#   "'s",
#   'nighttime',
#   'programming',
#   'block',
#   'Adult',
#   'Swim'],
#  ['The',
#   'series',
#   'follows',
#   'misadventures',
#   'Rick',
#   'Sanchez',
#   'cynical',
#   'mad',
#   'scientist',
#   'good-hearted',
#   'fretful',
#   'grandson',
#   'Morty',
#   'Smith',
#   'split',
#   'time',
#   'domestic',
#   'life',
#   'interdimensional',
#   'adventures',
#   'take',
#   'place',
#   'across',
#   'infinite',
#   'number',
#   'realities',
#   'often',
#   'traveling',
#   'planets',
#   'dimensions',
#   'portals',
#   'Rick',
#   "'s",
#   'flying',
#   'saucer'],
#  ['The',
#   'general',
#   'concept',
#   'Rick',
#   'Morty',
#   'relies',
#   'two',
#   'conflicting',
#   'scenarios',
#   'domestic',
#   'family',
#   'drama',
#   'misanthropic',
#   'grandfather',
#   'dragging',
#   'grandson',
#   'hijinks.Roiland',
#   'voiced',
#   'eponymous',
#   'characters',
#   'Chris',
#   'Parnell',
#   'Spencer',
#   'Grammer',
#   'Sarah',
#   'Chalke',
#   'voicing',
#   'rest',
#   'Rick',
#   'Morty',
#   "'s",
#   'family'],
#  ['The',
#   'series',
#   'originated',
#   'animated',
#   'short',
#   'parody',
#   'film',
#   'Back',
#   'Future',
#   'created',
#   'Roiland',
#   'Channel',
#   '101',
#   'short-film',
#   'festival',
#   'cofounded',
#   'Harmon'],
#  ['Since',
#   'debut',
#   'series',
#   'received',
#   'critical',
#   'acclaim',
#   'originality',
#   'creativity',
#   'humor'],
#  ['It',
#   'nominated',
#   'three',
#   'Primetime',
#   'Emmy',
#   'Awards',
#   'Outstanding',
#   'Animated',
#   'Program',
#   'award',
#   '2018',
#   '2020'],
#  ['The', 'series', 'also', 'received', 'two', 'Annie', 'Awards'],
#  ['At',
#   'times',
#   'series',
#   'viewed',
#   'television',
#   'comedy',
#   'adults',
#   '18',
#   '24'],
#  ['The',
#   'popularity',
#   'Rick',
#   'Morty',
#   'made',
#   'hundred-million',
#   'dollar',
#   'merchandising',
#   'media',
#   'franchise.The',
#   'sixth',
#   'season',
#   'premiered',
#   'September',
#   '4',
#   '2022',
#   'consists',
#   'ten',
#   'episodes'],
#  ['A',
#   'seventh',
#   'season',
#   'confirmed',
#   'part',
#   'long-term',
#   'deal',
#   'Cartoon',
#   'Network',
#   'ordered',
#   '70',
#   'new',
#   'episodes',
#   'renewed',
#   'series',
#   'tenth',
#   'season'],
#  ['Adult',
#   'Swim',
#   'cut',
#   'ties',
#   'Roiland',
#   '2023',
#   'amid',
#   'allegations',
#   'domestic',
#   'abuse',
#   'announced',
#   'would',
#   'recasting',
#   'roles',
#   'soundalike',
#   'actors']]

# %% [markdown]
# The top-10 most common tokens.

# %%
Counter([w for x in tokens_list for w in x]).most_common(10)
# Out:
# [('Rick', 6),
#  ('series', 6),
#  ('Morty', 5),
#  ('The', 5),
#  ('Roiland', 3),
#  ("'s", 3),
#  ('domestic', 3),
#  ('season', 3),
#  ('animated', 2),
#  ('created', 2)]

# %% [markdown]
# ## Stemming

# %% [markdown]
# Turning words into stems.

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
tokens_stem = [stemmer.stem(w) for x in tokens_list for w in x]

# %%
tokens_stem
# Out:
# ['rick',
#  'morti',
#  'american',
#  'adult',
#  'anim',
#  'scienc',
#  'fiction',
#  'sitcom',
#  'creat',
#  'justin',
#  'roiland',
#  'dan',
#  'harmon',
#  'cartoon',
#  'network',
#  "'s",
#  'nighttim',
#  'program',
#  'block',
#  'adult',
#  'swim',
#  'the',
#  'seri',
#  'follow',
#  'misadventur',
#  'rick',
#  'sanchez',
#  'cynic',
#  'mad',
#  'scientist',
#  'good-heart',
#  'fret',
#  'grandson',
#  'morti',
#  'smith',
#  'split',
#  'time',
#  'domest',
#  'life',
#  'interdimension',
#  'adventur',
#  'take',
#  'place',
#  'across',
#  'infinit',
#  'number',
#  'realiti',
#  'often',
#  'travel',
#  'planet',
#  'dimens',
#  'portal',
#  'rick',
#  "'s",
#  'fli',
#  'saucer',
#  'the',
#  'gener',
#  'concept',
#  'rick',
#  'morti',
#  'reli',
#  'two',
#  'conflict',
#  'scenario',
#  'domest',
#  'famili',
#  'drama',
#  'misanthrop',
#  'grandfath',
#  'drag',
#  'grandson',
#  'hijinks.roiland',
#  'voic',
#  'eponym',
#  'charact',
#  'chri',
#  'parnel',
#  'spencer',
#  'grammer',
#  'sarah',
#  'chalk',
#  'voic',
#  'rest',
#  'rick',
#  'morti',
#  "'s",
#  'famili',
#  'the',
#  'seri',
#  'origin',
#  'anim',
#  'short',
#  'parodi',
#  'film',
#  'back',
#  'futur',
#  'creat',
#  'roiland',
#  'channel',
#  '101',
#  'short-film',
#  'festiv',
#  'cofound',
#  'harmon',
#  'sinc',
#  'debut',
#  'seri',
#  'receiv',
#  'critic',
#  'acclaim',
#  'origin',
#  'creativ',
#  'humor',
#  'it',
#  'nomin',
#  'three',
#  'primetim',
#  'emmi',
#  'award',
#  'outstand',
#  'anim',
#  'program',
#  'award',
#  '2018',
#  '2020',
#  'the',
#  'seri',
#  'also',
#  'receiv',
#  'two',
#  'anni',
#  'award',
#  'at',
#  'time',
#  'seri',
#  'view',
#  'televis',
#  'comedi',
#  'adult',
#  '18',
#  '24',
#  'the',
#  'popular',
#  'rick',
#  'morti',
#  'made',
#  'hundred-million',
#  'dollar',
#  'merchandis',
#  'media',
#  'franchise.th',
#  'sixth',
#  'season',
#  'premier',
#  'septemb',
#  '4',
#  '2022',
#  'consist',
#  'ten',
#  'episod',
#  'a',
#  'seventh',
#  'season',
#  'confirm',
#  'part',
#  'long-term',
#  'deal',
#  'cartoon',
#  'network',
#  'order',
#  '70',
#  'new',
#  'episod',
#  'renew',
#  'seri',
#  'tenth',
#  'season',
#  'adult',
#  'swim',
#  'cut',
#  'tie',
#  'roiland',
#  '2023',
#  'amid',
#  'alleg',
#  'domest',
#  'abus',
#  'announc',
#  'would',
#  'recast',
#  'role',
#  'soundalik',
#  'actor']

# %%
Counter(tokens_stem).most_common(10)
# Out:
# [('rick', 6),
#  ('seri', 6),
#  ('morti', 5),
#  ('the', 5),
#  ('adult', 4),
#  ('anim', 3),
#  ('roiland', 3),
#  ("'s", 3),
#  ('domest', 3),
#  ('award', 3)]

# %% [markdown]
# ### Exercise
#
# Try other NLTK stemmers (e.g. SnowballStemmer, RegexpStemmer), you may need to download additional data packages, see https://www.nltk.org/data.html

# %%
from nltk.stem import SnowballStemmer, RegexpStemmer

stemmer_snow = SnowballStemmer('english')
tokens_stem_snow = [stemmer_snow.stem(w) for x in tokens_list for w in x]
print(tokens_stem_snow)
# Out:
# ['rick', 'morti', 'american', 'adult', 'anim', 'scienc', 'fiction', 'sitcom', 'creat', 'justin', 'roiland', 'dan', 'harmon', 'cartoon', 'network', "'s", 'nighttim', 'program', 'block', 'adult', 'swim', 'the', 'seri', 'follow', 'misadventur', 'rick', 'sanchez', 'cynic', 'mad', 'scientist', 'good-heart', 'fret', 'grandson', 'morti', 'smith', 'split', 'time', 'domest', 'life', 'interdimension', 'adventur', 'take', 'place', 'across', 'infinit', 'number', 'realiti', 'often', 'travel', 'planet', 'dimens', 'portal', 'rick', "'s", 'fli', 'saucer', 'the', 'general', 'concept', 'rick', 'morti', 'reli', 'two', 'conflict', 'scenario', 'domest', 'famili', 'drama', 'misanthrop', 'grandfath', 'drag', 'grandson', 'hijinks.roiland', 'voic', 'eponym', 'charact', 'chris', 'parnel', 'spencer', 'grammer', 'sarah', 'chalk', 'voic', 'rest', 'rick', 'morti', "'s", 'famili', 'the', 'seri', 'origin', 'anim', 'short', 'parodi', 'film', 'back', 'futur', 'creat', 'roiland', 'channel', '101', 'short-film', 'festiv', 'cofound', 'harmon', 'sinc', 'debut', 'seri', 'receiv', 'critic', 'acclaim', 'origin', 'creativ', 'humor', 'it', 'nomin', 'three', 'primetim', 'emmi', 'award', 'outstand', 'anim', 'program', 'award', '2018', '2020', 'the', 'seri', 'also', 'receiv', 'two', 'anni', 'award', 'at', 'time', 'seri', 'view', 'televis', 'comedi', 'adult', '18', '24', 'the', 'popular', 'rick', 'morti', 'made', 'hundred-million', 'dollar', 'merchandis', 'media', 'franchise.th', 'sixth', 'season', 'premier', 'septemb', '4', '2022', 'consist', 'ten', 'episod', 'a', 'seventh', 'season', 'confirm', 'part', 'long-term', 'deal', 'cartoon', 'network', 'order', '70', 'new', 'episod', 'renew', 'seri', 'tenth', 'season', 'adult', 'swim', 'cut', 'tie', 'roiland', '2023', 'amid', 'alleg', 'domest', 'abus', 'announc', 'would', 'recast', 'role', 'soundalik', 'actor']

# %% [markdown]
# ## Lemmatisation

# %% [markdown]
# Turning words into lemmas (entries in a dictionary). It requires knowledge of the context (typically the intended
# Part-of-Speech of a word in the context).

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jaspe\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\jaspe\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# POS tagging for lemmatisation.

# %%
nltk.download('averaged_perceptron_tagger')
tags_list = nltk.pos_tag_sents(tokens_list)
# tags_list
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jaspe\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# A heuristic to convert POS tags to the [four syntactic categories that wordnet recognizes (i.e. **noun**, **verb**, **adj** and **adv**)](https://wordnet.princeton.edu/):
# - `n` for nouns
# - `v` for verbs
# - `a` for adjectives
# - `r` for adverbs

# %%
tags_list
# Out:
# [[('Rick', 'NNP'),
#   ('Morty', 'NNP'),
#   ('American', 'NNP'),
#   ('adult', 'NN'),
#   ('animated', 'VBD'),
#   ('science', 'NN'),
#   ('fiction', 'NN'),
#   ('sitcom', 'NN'),
#   ('created', 'VBD'),
#   ('Justin', 'NNP'),
#   ('Roiland', 'NNP'),
#   ('Dan', 'NNP'),
#   ('Harmon', 'NNP'),
#   ('Cartoon', 'NNP'),
#   ('Network', 'NNP'),
#   ("'s", 'POS'),
#   ('nighttime', 'NN'),
#   ('programming', 'NN'),
#   ('block', 'NN'),
#   ('Adult', 'NNP'),
#   ('Swim', 'NNP')],
#  [('The', 'DT'),
#   ('series', 'NN'),
#   ('follows', 'VBZ'),
#   ('misadventures', 'NNS'),
#   ('Rick', 'NNP'),
#   ('Sanchez', 'NNP'),
#   ('cynical', 'JJ'),
#   ('mad', 'JJ'),
#   ('scientist', 'NN'),
#   ('good-hearted', 'JJ'),
#   ('fretful', 'JJ'),
#   ('grandson', 'NN'),
#   ('Morty', 'NNP'),
#   ('Smith', 'NNP'),
#   ('split', 'NN'),
#   ('time', 'NN'),
#   ('domestic', 'JJ'),
#   ('life', 'NN'),
#   ('interdimensional', 'JJ'),
#   ('adventures', 'NNS'),
#   ('take', 'VBP'),
#   ('place', 'NN'),
#   ('across', 'IN'),
#   ('infinite', 'JJ'),
#   ('number', 'NN'),
#   ('realities', 'NNS'),
#   ('often', 'RB'),
#   ('traveling', 'VBG'),
#   ('planets', 'NNS'),
#   ('dimensions', 'NNS'),
#   ('portals', 'NNS'),
#   ('Rick', 'NNP'),
#   ("'s", 'POS'),
#   ('flying', 'VBG'),
#   ('saucer', 'NN')],
#  [('The', 'DT'),
#   ('general', 'JJ'),
#   ('concept', 'NN'),
#   ('Rick', 'NNP'),
#   ('Morty', 'NNP'),
#   ('relies', 'VBZ'),
#   ('two', 'CD'),
#   ('conflicting', 'VBG'),
#   ('scenarios', 'NNS'),
#   ('domestic', 'JJ'),
#   ('family', 'NN'),
#   ('drama', 'NN'),
#   ('misanthropic', 'NN'),
#   ('grandfather', 'NN'),
#   ('dragging', 'VBG'),
#   ('grandson', 'NN'),
#   ('hijinks.Roiland', 'NN'),
#   ('voiced', 'VBD'),
#   ('eponymous', 'JJ'),
#   ('characters', 'NNS'),
#   ('Chris', 'NNP'),
#   ('Parnell', 'NNP'),
#   ('Spencer', 'NNP'),
#   ('Grammer', 'NNP'),
#   ('Sarah', 'NNP'),
#   ('Chalke', 'NNP'),
#   ('voicing', 'VBG'),
#   ('rest', 'NN'),
#   ('Rick', 'NNP'),
#   ('Morty', 'NNP'),
#   ("'s", 'POS'),
#   ('family', 'NN')],
#  [('The', 'DT'),
#   ('series', 'NN'),
#   ('originated', 'VBD'),
#   ('animated', 'JJ'),
#   ('short', 'JJ'),
#   ('parody', 'NN'),
#   ('film', 'NN'),
#   ('Back', 'NNP'),
#   ('Future', 'NNP'),
#   ('created', 'VBD'),
#   ('Roiland', 'NNP'),
#   ('Channel', 'NNP'),
#   ('101', 'CD'),
#   ('short-film', 'JJ'),
#   ('festival', 'NN'),
#   ('cofounded', 'VBD'),
#   ('Harmon', 'NNP')],
#  [('Since', 'IN'),
#   ('debut', 'NN'),
#   ('series', 'NN'),
#   ('received', 'VBD'),
#   ('critical', 'JJ'),
#   ('acclaim', 'NN'),
#   ('originality', 'NN'),
#   ('creativity', 'NN'),
#   ('humor', 'NN')],
#  [('It', 'PRP'),
#   ('nominated', 'VBD'),
#   ('three', 'CD'),
#   ('Primetime', 'NNP'),
#   ('Emmy', 'NNP'),
#   ('Awards', 'NNP'),
#   ('Outstanding', 'NNP'),
#   ('Animated', 'NNP'),
#   ('Program', 'NNP'),
#   ('award', 'NN'),
#   ('2018', 'CD'),
#   ('2020', 'CD')],
#  [('The', 'DT'),
#   ('series', 'NN'),
#   ('also', 'RB'),
#   ('received', 'VBD'),
#   ('two', 'CD'),
#   ('Annie', 'NNP'),
#   ('Awards', 'NNS')],
#  [('At', 'IN'),
#   ('times', 'NNS'),
#   ('series', 'NN'),
#   ('viewed', 'VBN'),
#   ('television', 'NN'),
#   ('comedy', 'NN'),
#   ('adults', 'NNS'),
#   ('18', 'CD'),
#   ('24', 'CD')],
#  [('The', 'DT'),
#   ('popularity', 'NN'),
#   ('Rick', 'NNP'),
#   ('Morty', 'NNP'),
#   ('made', 'VBD'),
#   ('hundred-million', 'NN'),
#   ('dollar', 'NN'),
#   ('merchandising', 'VBG'),
#   ('media', 'NNS'),
#   ('franchise.The', 'NN'),
#   ('sixth', 'JJ'),
#   ('season', 'NN'),
#   ('premiered', 'VBD'),
#   ('September', 'NNP'),
#   ('4', 'CD'),
#   ('2022', 'CD'),
#   ('consists', 'NNS'),
#   ('ten', 'VBP'),
#   ('episodes', 'NNS')],
#  [('A', 'DT'),
#   ('seventh', 'JJ'),
#   ('season', 'NN'),
#   ('confirmed', 'VBD'),
#   ('part', 'NN'),
#   ('long-term', 'JJ'),
#   ('deal', 'NN'),
#   ('Cartoon', 'NNP'),
#   ('Network', 'NNP'),
#   ('ordered', 'VBD'),
#   ('70', 'CD'),
#   ('new', 'JJ'),
#   ('episodes', 'NNS'),
#   ('renewed', 'VBN'),
#   ('series', 'NN'),
#   ('tenth', 'NN'),
#   ('season', 'NN')],
#  [('Adult', 'NNP'),
#   ('Swim', 'NNP'),
#   ('cut', 'VBD'),
#   ('ties', 'NNS'),
#   ('Roiland', 'NNP'),
#   ('2023', 'CD'),
#   ('amid', 'IN'),
#   ('allegations', 'NNS'),
#   ('domestic', 'JJ'),
#   ('abuse', 'NN'),
#   ('announced', 'VBD'),
#   ('would', 'MD'),
#   ('recasting', 'VBG'),
#   ('roles', 'NNS'),
#   ('soundalike', 'JJ'),
#   ('actors', 'NNS')]]

# %%
wordnet_tag = lambda t: 'a' if t == 'j' else (t if t in ['n', 'v', 'r'] else 'n')

# %% [markdown]
# Lemmatising

# %%
lemmatizer = WordNetLemmatizer()

# %%
tokens_lemma = [lemmatizer.lemmatize(w.lower(), pos=wordnet_tag(t[0].lower())) for x in tags_list for (w, t) in x]

# %%
tokens_lemma
# Out:
# ['rick',
#  'morty',
#  'american',
#  'adult',
#  'animate',
#  'science',
#  'fiction',
#  'sitcom',
#  'create',
#  'justin',
#  'roiland',
#  'dan',
#  'harmon',
#  'cartoon',
#  'network',
#  "'s",
#  'nighttime',
#  'programming',
#  'block',
#  'adult',
#  'swim',
#  'the',
#  'series',
#  'follow',
#  'misadventure',
#  'rick',
#  'sanchez',
#  'cynical',
#  'mad',
#  'scientist',
#  'good-hearted',
#  'fretful',
#  'grandson',
#  'morty',
#  'smith',
#  'split',
#  'time',
#  'domestic',
#  'life',
#  'interdimensional',
#  'adventure',
#  'take',
#  'place',
#  'across',
#  'infinite',
#  'number',
#  'reality',
#  'often',
#  'travel',
#  'planet',
#  'dimension',
#  'portal',
#  'rick',
#  "'s",
#  'fly',
#  'saucer',
#  'the',
#  'general',
#  'concept',
#  'rick',
#  'morty',
#  'rely',
#  'two',
#  'conflict',
#  'scenario',
#  'domestic',
#  'family',
#  'drama',
#  'misanthropic',
#  'grandfather',
#  'drag',
#  'grandson',
#  'hijinks.roiland',
#  'voice',
#  'eponymous',
#  'character',
#  'chris',
#  'parnell',
#  'spencer',
#  'grammer',
#  'sarah',
#  'chalke',
#  'voice',
#  'rest',
#  'rick',
#  'morty',
#  "'s",
#  'family',
#  'the',
#  'series',
#  'originate',
#  'animated',
#  'short',
#  'parody',
#  'film',
#  'back',
#  'future',
#  'create',
#  'roiland',
#  'channel',
#  '101',
#  'short-film',
#  'festival',
#  'cofounded',
#  'harmon',
#  'since',
#  'debut',
#  'series',
#  'receive',
#  'critical',
#  'acclaim',
#  'originality',
#  'creativity',
#  'humor',
#  'it',
#  'nominate',
#  'three',
#  'primetime',
#  'emmy',
#  'award',
#  'outstanding',
#  'animated',
#  'program',
#  'award',
#  '2018',
#  '2020',
#  'the',
#  'series',
#  'also',
#  'receive',
#  'two',
#  'annie',
#  'award',
#  'at',
#  'time',
#  'series',
#  'view',
#  'television',
#  'comedy',
#  'adult',
#  '18',
#  '24',
#  'the',
#  'popularity',
#  'rick',
#  'morty',
#  'make',
#  'hundred-million',
#  'dollar',
#  'merchandise',
#  'medium',
#  'franchise.the',
#  'sixth',
#  'season',
#  'premier',
#  'september',
#  '4',
#  '2022',
#  'consists',
#  'ten',
#  'episode',
#  'a',
#  'seventh',
#  'season',
#  'confirm',
#  'part',
#  'long-term',
#  'deal',
#  'cartoon',
#  'network',
#  'order',
#  '70',
#  'new',
#  'episode',
#  'renew',
#  'series',
#  'tenth',
#  'season',
#  'adult',
#  'swim',
#  'cut',
#  'tie',
#  'roiland',
#  '2023',
#  'amid',
#  'allegation',
#  'domestic',
#  'abuse',
#  'announce',
#  'would',
#  'recast',
#  'role',
#  'soundalike',
#  'actor']

# %%
Counter(tokens_lemma).most_common(10)
# Out:
# [('rick', 6),
#  ('series', 6),
#  ('morty', 5),
#  ('the', 5),
#  ('adult', 4),
#  ('roiland', 3),
#  ("'s", 3),
#  ('domestic', 3),
#  ('award', 3),
#  ('season', 3)]
