# %% [markdown]
# ## Part 2: Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("..\Data\weather.csv")

# %%
df.head() # read first 5 records
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2007-11-01  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  2007-11-02  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  2007-11-03  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  2007-11-04  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  2007-11-05  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0          NW           30.0         SW  ...          29       1019.7
# 1         ENE           39.0          E  ...          36       1012.4
# 2          NW           85.0          N  ...          69       1009.5
# 3          NW           54.0        WNW  ...          56       1005.5
# 4         SSE           50.0        SSE  ...          49       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %% [markdown]
# ### head()

# %%
df.head(10) # read first 10 records
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2007-11-01  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  2007-11-02  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  2007-11-03  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  2007-11-04  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  2007-11-05  Canberra      7.6     16.1       2.8          5.6      10.6
# 5  2007-11-06  Canberra      6.2     16.9       0.0          5.8       8.2
# 6  2007-11-07  Canberra      6.1     18.2       0.2          4.2       8.4
# 7  2007-11-08  Canberra      8.3     17.0       0.0          5.6       4.6
# 8  2007-11-09  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  2007-11-10  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0          NW           30.0         SW  ...          29       1019.7
# ...

# %%
df.head(20) # read first 20 records
# Out:
#           Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2007-11-01  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   2007-11-02  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   2007-11-03  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   2007-11-04  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   2007-11-05  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   2007-11-06  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   2007-11-07  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   2007-11-08  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   2007-11-09  Canberra      8.8     19.5       0.0          4.0       4.1
# 9   2007-11-10  Canberra      8.4     22.8      16.2          5.4       7.7
# 10  2007-11-11  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %% [markdown]
# ### tail()

# %%
df.tail(10)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 356  2008-10-22  Canberra      3.4     15.0       0.8          4.8      11.7
# 357  2008-10-23  Canberra      3.2     18.0       0.0          7.4      12.2
# 358  2008-10-24  Canberra      0.9     20.7       0.0          5.4       8.4
# 359  2008-10-25  Canberra      3.3     25.5       0.0          5.2      10.8
# 360  2008-10-26  Canberra      7.9     26.1       0.0          6.8       3.5
# 361  2008-10-27  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  2008-10-28  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  2008-10-29  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  2008-10-30  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  2008-10-31  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# ...

# %%
df.tail(20)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 346  2008-10-12  Canberra      4.5     23.9       0.0          4.8      11.7
# 347  2008-10-13  Canberra      6.7     26.1       0.0          6.2       7.5
# 348  2008-10-14  Canberra     11.9     21.1      13.2          6.6       NaN
# 349  2008-10-15  Canberra      9.2     19.6       0.6          3.4      10.4
# 350  2008-10-16  Canberra      4.4     21.0       0.0          4.2      12.2
# 351  2008-10-17  Canberra      5.0     24.1       0.0          6.2      12.0
# 352  2008-10-18  Canberra      6.7     24.7       0.0          5.4       8.6
# 353  2008-10-19  Canberra      8.3     28.5       0.0          5.8       9.8
# 354  2008-10-20  Canberra     11.3     27.4       0.2          7.6      12.1
# 355  2008-10-21  Canberra      9.0     20.6       0.0          9.0       6.2
# 356  2008-10-22  Canberra      3.4     15.0       0.8          4.8      11.7
# ...

# %%
df.tail(50)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 316  2008-09-12  Canberra     -0.5     21.6       0.0          5.0       9.9
# 317  2008-09-13  Canberra      9.0     25.5       0.0          5.6      10.2
# 318  2008-09-14  Canberra     13.1     19.4       9.8          8.8       6.0
# 319  2008-09-15  Canberra      8.7     19.7       1.6          5.2       8.0
# 320  2008-09-16  Canberra      3.9     13.2       3.4          6.6      11.0
# 321  2008-09-17  Canberra      0.7     14.1       0.0          5.6       9.0
# 322  2008-09-18  Canberra      1.1     18.0       0.0          1.6       8.6
# 323  2008-09-19  Canberra      5.1     23.3       0.0          3.6      10.3
# 324  2008-09-20  Canberra      7.5     23.3       0.0          6.8      10.9
# 325  2008-09-21  Canberra      4.7     19.5       0.0         10.0      11.0
# 326  2008-09-22  Canberra      3.2     21.9       0.0          6.8       5.2
# ...

# %% [markdown]
# ### Select range of rows

# %% [markdown]
# #### Rows

# %%
range1 = df[0:10] # [0,9]
range2 = df[10:20] # [10,19]

# %%
range1
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2007-11-01  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  2007-11-02  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  2007-11-03  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  2007-11-04  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  2007-11-05  Canberra      7.6     16.1       2.8          5.6      10.6
# 5  2007-11-06  Canberra      6.2     16.9       0.0          5.8       8.2
# 6  2007-11-07  Canberra      6.1     18.2       0.2          4.2       8.4
# 7  2007-11-08  Canberra      8.3     17.0       0.0          5.6       4.6
# 8  2007-11-09  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  2007-11-10  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0          NW           30.0         SW  ...          29       1019.7
# ...

# %% [markdown]
# #### columns

# %%
colByIndex = df['Location']
colByDot = df.Location

# %%
colByIndex
# Out:
# 0      Canberra
# 1      Canberra
# 2      Canberra
# 3      Canberra
# 4      Canberra
#          ...
# 361    Canberra
# 362    Canberra
# 363    Canberra
# 364    Canberra
# 365    Canberra
# Name: Location, Length: 366, dtype: object

# %%
colByDot
# Out:
# 0      Canberra
# 1      Canberra
# 2      Canberra
# 3      Canberra
# 4      Canberra
#          ...
# 361    Canberra
# 362    Canberra
# 363    Canberra
# 364    Canberra
# 365    Canberra
# Name: Location, Length: 366, dtype: object

# %% [markdown]
# ##### Multiple columns

# %%
Multicols = df[['Location','MaxTemp']]
Multicols
# Out:
#      Location  MaxTemp
# 0    Canberra     24.3
# 1    Canberra     26.9
# 2    Canberra     23.4
# 3    Canberra     15.5
# 4    Canberra     16.1
# ..        ...      ...
# 361  Canberra     30.7
# 362  Canberra     28.4
# 363  Canberra     19.9
# 364  Canberra     26.9
# 365  Canberra     30.2
#
# [366 rows x 2 columns]

# %% [markdown]
# ### Data Frame Attributes

# %%
df.dtypes # list the data types of the columns
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
df.columns # list the columns names
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.axes # list the row labels and column names
# Out:
# [RangeIndex(start=0, stop=366, step=1),
#  Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#         'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#         'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#         'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#         'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#        dtype='object')]

# %%
df.size # Number of elements
# Out:
# 8784

# %% [markdown]
# ### Missing values
# - select rows have at least one missing value

# %%
missing1 = df[df.isnull().any(axis=1)]
# missing2 = df[df.isnull().all(axis=1)]

# %%
missing1
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 113  2008-02-22  Canberra     12.7     28.6       6.6          3.2       8.6
# 118  2008-02-27  Canberra     11.7     27.6       0.0          7.8       8.1
# 127  2008-03-07  Canberra     10.8     29.2       0.0          8.4       7.5
# 138  2008-03-18  Canberra     12.5     29.9       0.0          5.8      10.7
# 140  2008-03-20  Canberra     11.5     29.3       0.0          5.2       8.0
# 174  2008-04-23  Canberra      7.5     19.0       0.0          4.0       6.8
# 176  2008-04-25  Canberra      5.0     20.9       0.0          2.0       8.9
# 180  2008-04-29  Canberra     -2.1     13.8       0.2          1.8       9.5
# 189  2008-05-08  Canberra     -0.2     18.1       0.0          4.4       9.4
# 193  2008-05-12  Canberra      9.4     19.2       0.0          2.2       7.7
# 195  2008-05-14  Canberra      2.2     18.6       0.0          2.0       9.2
# ...

# %% [markdown]
# #### Descriptive statistics

# %%
df.Location.describe()
# Out:
# count          366
# unique           1
# top       Canberra
# freq           366
# Name: Location, dtype: object

# %%
df[['Location','MaxTemp']].describe()
# Out:
#           MaxTemp
# count  366.000000
# mean    20.550273
# std      6.690516
# min      7.600000
# 25%     15.025000
# 50%     19.650000
# 75%     25.500000
# max     35.800000

# %% [markdown]
# ##### Correlation

# %%
df['MinTemp'].corr(df['MaxTemp'])
# Out:
# 0.7524707945910016

# %% [markdown]
# ##### View Unique Values

# %%
df.RainTomorrow.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ### DataFrame.method

# %%
df.MaxTemp.min()
# Out:
# 7.6

# %%
df.MaxTemp.max()
# Out:
# 35.8

# %%
df.MaxTemp.count()
# Out:
# 366

# %%
df.MaxTemp.mean()
# Out:
# 20.55027322404372

# %%
df.MaxTemp.median()
# Out:
# 19.65

# %%
df.MaxTemp.mode()
# Out:
# 0    11.6
# 1    12.2
# 2    14.1
# 3    14.7
# 4    14.8
# 5    15.5
# 6    18.0
# 7    18.5
# 8    18.9
# 9    20.9
# Name: MaxTemp, dtype: float64

# %%
df.MaxTemp.mad() # mean absolute deviation value
# Out:
# 5.5811669503419

# %%
df.MaxTemp.var()
# Out:
# 44.7629999251441

# %%
df.MaxTemp.std()
# Out:
# 6.690515669598577

# %%
df.MaxTemp.skew()
# Out:
# 0.3503773396747656

# %%
df.MaxTemp.kurt()
# Out:
# -0.7451301960084957

# %%
pd.crosstab(df.RainTomorrow,df.MinTemp)
# Out:
# MinTemp       -5.3   -3.7   -3.5   -3.4   -3.3   -3.1   -2.9   -2.8   -2.7   \
# RainTomorrow
# No                1      2      2      1      1      1      1      2      2
# Yes               0      0      0      0      0      0      0      0      0
#
# MinTemp       -2.6   ...   17.0   17.1   17.2   17.5   17.6   17.9   18.0  \
# RainTomorrow         ...
# No                1  ...      1      0      1      2      0      1      0
# Yes               0  ...      0      1      1      0      1      1      1
#
# MinTemp        18.2   19.9   20.9
# RainTomorrow
# No                0      0      0
# Yes               1      1      1
#
# [2 rows x 180 columns]

# %%
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.752471  0.201939     0.649930  0.035711
# MaxTemp        0.752471  1.000000 -0.073560     0.690026  0.452064
# Rainfall       0.201939 -0.073560  1.000000    -0.007293 -0.150990
# Evaporation    0.649930  0.690026 -0.007293     1.000000  0.318025
# Sunshine       0.035711  0.452064 -0.150990     0.318025  1.000000
# WindGustSpeed  0.218020  0.109672  0.096190     0.288477  0.095843
# WindSpeed9am   0.127542 -0.216814  0.219637     0.068929 -0.064522
# WindSpeed3pm  -0.065922 -0.167873  0.056008     0.048601  0.072573
# Humidity9am   -0.207897 -0.359602  0.150109    -0.519587 -0.499017
# Humidity3pm   -0.040709 -0.533327  0.289013    -0.391780 -0.759429
# Pressure9am   -0.501707 -0.290883 -0.331581    -0.381906  0.006276
# Pressure3pm   -0.498007 -0.379394 -0.250218    -0.391093 -0.036201
# Cloud9am       0.215776 -0.175730  0.180046    -0.106007 -0.681092
# ...

# %%
vars_with_na = [var for var in df.columns if df[var].isnull().sum() > 0]
print (vars_with_na)
# Out:
# ['Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am']

# %%
df.isnull()
# Out:
#       Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    False     False    False    False     False        False     False
# 1    False     False    False    False     False        False     False
# 2    False     False    False    False     False        False     False
# 3    False     False    False    False     False        False     False
# 4    False     False    False    False     False        False     False
# ..     ...       ...      ...      ...       ...          ...       ...
# 361  False     False    False    False     False        False     False
# 362  False     False    False    False     False        False     False
# 363  False     False    False    False     False        False     False
# 364  False     False    False    False     False        False     False
# 365  False     False    False    False     False        False     False
#
#      WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# ...

# %%
missing_counts = df.isnull().sum()

missing_counts
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
# Sort variables by the count of missing values in descending order
sorted_missing = missing_counts.sort_values(ascending=False)

# Print the sorted list of variables with missing values
print(sorted_missing)
# Out:
# WindDir9am       31
# WindSpeed9am      7
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir3pm        1
# Date              0
# Pressure9am       0
# RISK_MM           0
# RainToday         0
# Temp3pm           0
# Temp9am           0
# Cloud3pm          0
# Cloud9am          0
# Pressure3pm       0
# WindSpeed3pm      0
# Humidity3pm       0
# Humidity9am       0
# Location          0
# Evaporation       0
# Rainfall          0
# MaxTemp           0
# MinTemp           0
# RainTomorrow      0
# dtype: int64

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### hist

# %%
df.MaxTemp.plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['MaxTemp'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['MaxTemp','MinTemp']].plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['MaxTemp','MinTemp']].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['MaxTemp'].plot(kind='kde')  # density function
# Out:
# <AxesSubplot:ylabel='Density'>
